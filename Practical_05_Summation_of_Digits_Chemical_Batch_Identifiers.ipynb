# %% [markdown]
# # Practical 5: Summation of Digits – Chemical Batch Numbers and Identifiers
#
# ### Computer Programming Lab – Chemical Engineering
# **Syllabus Experiment:** Summation of digits extended to processing chemical batch numbers or identifiers
# **Environment:** GitHub Codespaces + Jupyter Notebook + GitHub Copilot
#
# ---
#
# ## Important: Exact Syllabus Context
#
# The syllabus line is:
#
# > **Summation of digits extended to processing chemical batch numbers or identifiers**
#
# This practical therefore starts with the basic programming problem of **finding the sum of digits of a number**, and then extends it to a realistic chemical-industry situation where a batch number or identifier contains digits that need to be extracted and processed.
#
# ## How we will use AI Copilot
#
# GitHub Copilot is your **AI coding assistant**. Use it to understand the logic, get hints, debug errors and improve your program.
#
# **Do not ask Copilot to write the complete practical at the beginning.** First understand how digits are extracted and summed. Then use Copilot for explanations and debugging.
#
# At the end, you should be able to explain your own program without depending on Copilot.

# %% [markdown]
# ## 1. Learning Objectives
#
# After completing this practical, you should be able to:
#
# 1. Understand how the digits of an integer can be extracted using division and remainder operations.
# 2. Use a loop to process the digits one by one.
# 3. Calculate the sum of digits of a number.
# 4. Handle numbers with different numbers of digits.
# 5. Understand the difference between a number and a batch identifier stored as text.
# 6. Extract and process digits from a chemical batch number or identifier.
# 7. Validate batch-number input.
# 8. Extend the basic digit-summation logic to a simple chemical-industry application.
# 9. Use GitHub Copilot to explain and debug the program.

# %% [markdown]
# ## 2. Chemical Industry Context
#
# Chemical plants and laboratories commonly use **batch numbers, sample IDs, lot numbers and equipment identifiers** to track materials and process records.
#
# For example, an organization may use identifiers such as:
#
# ```text
# 20260815
# 24073105
# CHEM20260815
# BATCH24073105
# ```
#
# The exact format depends on the organization's tracking system. In this practical, we use **illustrative identifiers only**.
#
# One simple processing operation is to calculate the **sum of the digits** contained in an identifier. This is not a real-world chemical property; it is a programming exercise showing how a basic numerical algorithm can be extended to process industry identifiers.

# %% [markdown]
# ## 3. Activity 1 – Sum the Digits of an Integer
#
# Start with the basic problem.
#
# For example:
#
# ```text
# Number = 5827
# ```
#
# The sum of its digits is:
#
# ```text
# 5 + 8 + 2 + 7 = 22
# ```
#
# ### Think before coding
#
# How can you obtain the **last digit** of an integer using Python?
#
# How can you remove the last digit so that the next digit can be processed?

# %%
# Activity 1
# Experiment with % and // using a number such as 5827.
# Find the last digit and then remove the last digit.
number = 4657
last_digit = number % 10
print ("last_digit:",last_digit)
number = number // 10
print("number without last digit:",number)
# Out:
# last_digit: 7
# number without last digit: 465

# %% [markdown]
# ## 4. Activity 2 – Build the Digit-Summation Loop
#
# Now create an algorithm that repeatedly extracts the last digit and adds it to a running total.
#
# For each iteration:
#
# 1. Extract the last digit.
# 2. Add it to `digit_sum`.
# 3. Remove the last digit from the number.
# 4. Continue until no digits remain.
#
# ### Example
#
# For `5827`, your program should process:
#
# ```text
# 7 → 2 → 8 → 5
# ```
#
# and finally produce:
#
# ```text
# 22
# ```

# %% [markdown]
# ### Copilot Activity 2 – Loop Logic
#
# Ask Copilot:
#
# > Explain the logic of a while loop that repeatedly extracts the last digit of an integer, adds it to a running sum, and removes the last digit. Do not give me the complete Python code.

# %%
# Activity 2
# Write a while-loop program to calculate the sum of digits.
number = 5827
sum_of_digits = 0
while number > 0:
    last_digit = number % 10
    sum_of_digit += last_digit
    number = number // 10 
print("sum of digits:",sum_of_digit)
# Out:
# sum of digits: 44

# %% [markdown]
# ## 5. Activity 3 – Test Different Numbers
#
# Test your program with:
#
# | Number | Expected digit sum |
# |---:|---:|
# | 5827 | 22 |
# | 10025 | 8 |
# | 98765 | 35 |
# | 7 | 7 |
# | 123456789 | 45 |
#
# Also test `0`.
#
# ### Think about it
#
# What should the sum of the digits of `0` be?

# %%
# Activity 3
# Test your digit-summation program with the values from the table.
number = int(input("enter a number"))
print("calculating the sum of digits for:", number)
sum_of_digits = 0
while number > 0:
    last_digit = number % 10
    sum_of_digits += last_digit
    number = number // 10 
print("sum of digits:",sum_of_digits)
# Out:
# calculating the sum of digits for: 1234
# sum of digits: 10

# %% [markdown]
# ## 6. Activity 4 – Convert a Chemical Batch Number into a Digit Sum
#
# Now connect the basic algorithm with the syllabus application.
#
# Consider the illustrative batch number:
#
# ```text
# 20260815
# ```
#
# Interpret it simply as a batch identifier and calculate the sum of its digits.
#
# ### Important concept
#
# If an identifier contains leading zeros, such as:
#
# ```text
# 001245
# ```
#
# converting it directly to an integer will remove the leading zeros.
#
# Therefore, when the value is an **identifier**, it is often better to store it as a string.

# %% [markdown]
# ### Copilot Activity 3 – Number vs Identifier
#
# Ask Copilot:
#
# > Explain why a chemical batch number or sample ID should often be stored as a Python string instead of an integer, especially when it can contain leading zeros. Give a simple example. Do not write the complete program.

# %%
# Activity 4
# Store a batch number as a string and calculate the sum of its digits.
batch_number = 1245
sum_of_digits = 0
for digit in str(batch_number):
    sum_of_digits += int(digit)
print("sum of digits:",sum_of_digits)
# Out:
# sum of digits: 12

# %% [markdown]
# ## 7. Activity 5 – Extract Digits from a Batch Identifier
#
# Consider these illustrative identifiers:
#
# ```text
# CHEM20260815
# BATCH24073105
# LAB001245
# SAMPLE2026007
# ```
#
# These identifiers contain letters and digits.
#
# Your task is to process the identifier and calculate the sum of **only the digits**.
#
# For example, for:
#
# ```text
# LAB001245
# ```
#
# the digits are:
#
# ```text
# 0 + 0 + 1 + 2 + 4 + 5 = 12
# ```

# %% [markdown]
# ### Copilot Activity 4 – Processing Characters
#
# Ask Copilot:
#
# > I have a chemical batch identifier such as LAB001245. Explain how a Python for loop can inspect each character and identify which characters are digits. Mention the role of isdigit(). Do not write the complete program.

# %%
# Activity 5
# Calculate the sum of only the digits contained in a batch identifier string.
batch_number = "asd3452fgm"
sum_of_digits = 0
for char in batch_number:
    if char.isdigit():
        sum_of_digits += int(char)
print("sum of digits in batch identifier:",sum_of_digits)
# Out:
# sum of digits in batch identifier: 14

# %% [markdown]
# ## 8. Activity 6 – Create a Batch Identifier Analyzer
#
# Build a program that accepts a chemical batch identifier from the user.
#
# The program should:
#
# 1. Accept the identifier as a string.
# 2. Examine each character.
# 3. Ignore letters and other non-digit characters.
# 4. Add all digits.
# 5. Count how many digits were found.
# 6. Display the digit sum.
#
# For example:
#
# ```text
# Batch ID: CHEM20260815
# Number of digits: 8
# Digit sum: 30
# ```

# %% [markdown]
# ### Copilot Activity 5 – Program Design
#
# Ask Copilot:
#
# > Help me design a beginner Python batch-ID analyzer that loops through a string, identifies digits using isdigit(), counts the digits and calculates their sum. Explain the logic without writing the complete solution.

# %%
# Activity 6
# Build your chemical batch identifier analyzer.
n = 0
batch_number = "asd3452fgm"
sum_of_digits = 0
for char in batch_number:
    if char.isdigit():
        sum_of_digits += int(char)
        n = n+1
print("sum of digits in batch identifier:",sum_of_digits)
print("number of digits in batch identifier:",n)
print("Analyzing batch identifier:", batch_number)
# Out:
# sum of digits in batch identifier: 14
# number of digits in batch identifier: 4
# Analyzing batch identifier: asd3452fgm

# %% [markdown]
# ## 9. Activity 7 – Add Validation
#
# A batch identifier should not be an empty string.
#
# Also consider an input such as:
#
# ```text
# ABCDEF
# ```
#
# It contains no digits.
#
# Modify your program so that it clearly reports:
#
# - empty input
# - an identifier containing no digits
# - a valid identifier containing one or more digits

# %% [markdown]
# ### Copilot Activity 6 – Validation
#
# Ask Copilot:
#
# > Suggest simple validation rules for a beginner Python program that calculates the digit sum of a chemical batch identifier. The program should detect empty input and an identifier containing no digits. Do not write the complete program.

# %%
# Activity 7
# Add input validation to your batch identifier analyzer.
number = input("Enter a batch identifier: ")
print("Analyzing batch identifier:", number)
if (number == ''):
    print("Error: Batch identifier cannot be empty.")
else:
    number_of_digits = 0
    sum_of_digits = 0
    for char in number:
        if char.isdigit():
            sum_of_digits += int(char)
            number_of_digits += 1
    if number_of_digits == 0:
        print("Error: Batch identifier must contain at least one digit.")
    else:

        print("Sum of digits in batch identifier:", sum_of_digits)
        print("Number of digits in batch identifier:", number_of_digits)
        print("Analyzing batch identifier:", number)
# Out:
# Analyzing batch identifier: jfhjfj657
# Sum of digits in batch identifier: 18
# Number of digits in batch identifier: 3
# Analyzing batch identifier: jfhjfj657

# %% [markdown]
# ## 10. Activity 8 – Compare Two Batch Identifiers
#
# Extend your program to accept two batch identifiers.
#
# For each identifier, calculate:
#
# - number of digits
# - digit sum
#
# Then compare the digit sums.
#
# Example:
#
# ```text
# Batch 1: CHEM20260815
# Batch 2: BATCH24073105
#
# Batch 1 digit sum: ...
# Batch 2 digit sum: ...
#
# Higher digit sum: Batch ...
# ```

# %%
# Activity 8
# Compare the digit sums of two batch identifiers.
batch_number_1 = input("Enter the first batch identifier: ")
print("Analyzing batch identifier:", batch_number_1)
if (batch_number_1 == ''):
    print("Error: Batch identifier cannot be empty.")
else:
    number_of_digits = 0
    sum_of_digits = 0
    for char in batch_number_1:
        if char.isdigit():
            sum_of_digits += int(char)
            number_of_digits += 1
    if number_of_digits == 0:
        print("Error: Batch identifier must contain at least one digit.")
    else:

        print("Sum of digits in batch identifier:", sum_of_digits)
        print("Number of digits in batch identifier:", number_of_digits)
        print("Analyzing batch identifier:", batch_number_1)

batch_number_2 = input("Enter the second batch identifier: ")
print("Analyzing batch identifier:", batch_number_2)
if (batch_number_2 == ''):
    print("Error: Batch identifier cannot be empty.")
else:   
    number_of_digits = 0
    sum_of_digits = 0
    for char in batch_number_2:
        if char.isdigit():
            sum_of_digits += int(char)
            number_of_digits += 1
    if number_of_digits == 0:
        print("Error: Batch identifier must contain at least one digit.")
    else:

        print("Sum of digits in batch identifier:", sum_of_digits)
        print("Number of digits in batch identifier:", number_of_digits)
        print("Analyzing batch identifier:", batch_number_2)
# Out:
# Analyzing batch identifier: 435fzdf
# Sum of digits in batch identifier: 12
# Number of digits in batch identifier: 3
# Analyzing batch identifier: 435fzdf
# Analyzing batch identifier: rgrfvdr64
# Sum of digits in batch identifier: 10
# Number of digits in batch identifier: 2
# Analyzing batch identifier: rgrfvdr64

# %% [markdown]
# ## 11. Copilot Debugging Challenge
#
# The following program contains a logical error.
#
# Study it **before** asking Copilot.
#
# ```python
# batch_id = "LAB001245"
# digit_sum = 0
#
# for ch in batch_id:
#     if ch.isdigit:
#         digit_sum += int(ch)
#
# print("Digit sum:", digit_sum)
# ```
#
# ### Your task
#
# 1. Run the program.
# 2. Observe the error.
# 3. Identify the problem with `isdigit`.
# 4. Ask Copilot:
#
# > My Python program checks whether a character is a digit using ch.isdigit, but it gives an error when I run it. Explain what I have forgotten and why.
#
# 5. Correct the program yourself.

# %%
# Run the intentionally incorrect program here.
batch_id = "LAB001245"
digit_sum = 0

for ch in batch_id:
    if ch.isdigit:
        digit_sum += int(ch)

print("Digit sum:", digit_sum)

# %% [markdown]
# ### Explain the error in your own words
#
# Write your explanation here before continuing.

# %% [markdown]
# ## 12. Testing Your Batch Identifier Analyzer
#
# Use the following test cases:
#
# | Test | Batch identifier | Expected observation |
# |---|---|---|
# | 1 | `CHEM20260815` | Digits found and summed |
# | 2 | `BATCH24073105` | Digits found and summed |
# | 3 | `LAB001245` | Leading zeros preserved |
# | 4 | `SAMPLE2026007` | Digits found and summed |
# | 5 | `ABCDEF` | No digits |
# | 6 | `` (empty) | Invalid input |
# | 7 | `123456789` | All characters are digits |
# | 8 | `A1-B2-C3` | Only digits are summed |
#
# For every test, check whether your program behaves as expected.

# %% [markdown]
# ## 13. Final Mini-Project – Chemical Batch Identifier Analyzer
#
# Build one clean Python program that processes a chemical batch/sample identifier.
#
# Your final program should:
#
# 1. Accept a batch identifier from the user.
# 2. Treat it as a string.
# 3. Validate that the input is not empty.
# 4. Examine each character using a loop.
# 5. Identify digits using `isdigit()`.
# 6. Calculate the sum of all digits.
# 7. Count the number of digits.
# 8. Display the digits found.
# 9. Display the digit count.
# 10. Display the digit sum.
# 11. Clearly report if the identifier contains no digits.
#
# ### Optional extension
#
# Add a second batch ID and compare the two digit sums.
#
# **Keep the program beginner-friendly. Do not use regular expressions or advanced libraries in the main solution.**

# %%
# FINAL PROGRAM
# Chemical Batch Identifier Analyzer
# Write your clean final solution here.

# %% [markdown]
# ## 14. Final Copilot Review
#
# After completing your final program, ask Copilot:
#
# > Review my Python chemical batch identifier analyzer. Check whether I correctly process the identifier character by character, identify digits, calculate the digit count and digit sum, and handle empty or digit-free identifiers. Do not rewrite my program; identify possible issues and explain them.
#
# Make changes only after you understand the feedback.

# %% [markdown]
# ## 15. Reflection – What Did You Learn?
#
# Answer in your own words:
#
# 1. How can `%` and `//` be used to extract digits from an integer?
# 2. Why is a loop useful for digit summation?
# 3. Why should a batch identifier usually be stored as a string?
# 4. What does `isdigit()` do?
# 5. Why are leading zeros important in identifiers?
# 6. How is summation of digits extended to chemical batch numbers or identifiers?
# 7. What error did you find in the debugging challenge?
# 8. What did Copilot help you understand or debug?
# 9. Which part of the program did you write or correct yourself after receiving a Copilot hint?
# 10. Can you explain your final program without opening Copilot?

# %% [markdown]
# ## 16. Submission Checklist
#
# - [ ] I calculated the sum of digits of an integer.
# - [ ] I used a loop to process digits.
# - [ ] I tested different integer values.
# - [ ] I understood `%` and `//` for digit extraction.
# - [ ] I processed a chemical batch/sample identifier as a string.
# - [ ] I used `isdigit()` to identify digits.
# - [ ] I handled leading zeros correctly.
# - [ ] I added input validation.
# - [ ] I tested identifiers containing letters, digits and separators.
# - [ ] I used Copilot for explanation and debugging rather than simply copying a complete solution.
# - [ ] I can explain my final program.
# - [ ] I saved the completed notebook in my GitHub repository.

# %% [markdown]
# ## 17. Suggested Evaluation – Faculty Use
#
# | Component | Marks |
# |---|---:|
# | Basic digit extraction and summation | 2 |
# | Correct loop implementation | 2 |
# | Batch/sample identifier processing | 2 |
# | Input validation and edge cases | 1 |
# | Testing and debugging | 1 |
# | Copilot usage and explanation | 1 |
# | Student's ability to explain/modify the program | 1 |
# | **Total** | **10** |
#
# **Faculty note:** During evaluation, give the student a new batch identifier such as `CHEM25090817` or `LAB003021` and ask them to predict the digit sum before running the program. Also ask why the identifier should be treated as a string.
